# %% [markdown]
# <a href="https://colab.research.google.com/github/Zuleika28/ai2023zuleika/blob/main/Pandas_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
tmp=pd.Series(data=[100,200,300,400],index=['carlos','juan','mario','rosita'])

# %%
print(tmp)
# Out:
# carlos    100
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp[-2])
# Out:
# 300

# %%
tmp*2
# Out:
# carlos    200
# juan      400
# mario     600
# rosita    800
# dtype: int64

# %%
tmp[[1,2,3]]
# Out:
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
print(tmp[[1,2,3]])
# Out:
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.index
# Out:
# Index(['carlos', 'juan', 'mario', 'rosita'], dtype='object')

# %%
#Crear diccionario
my_dict = {'name':'John','age': 25, 'city':'New York'}

# %%
aux={'one':pd.Series([1,2,3],index=['apple','ball','clock']),
     'two':pd.Series([10,20,30],index=['pineaple','watermelon','banana'])}

# %%
aux
# Out:
# {'one': apple    1
#  ball     2
#  clock    3
#  dtype: int64,
#  'two': pineaple      10
#  watermelon    20
#  banana        30
#  dtype: int64}

# %%
df=pd.DataFrame(aux)

# %%
df.shape
# Out:
# (6, 2)

# %%
df
# Out:
#             one   two
# apple       1.0   NaN
# ball        2.0   NaN
# banana      NaN  30.0
# clock       3.0   NaN
# pineaple    NaN  10.0
# watermelon  NaN  20.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'banana', 'clock', 'pineaple', 'watermelon'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['three']=df['one']*df['two']

# %%
df
# Out:
#             one   two  three
# apple       1.0   NaN    NaN
# ball        2.0   NaN    NaN
# banana      NaN  30.0    NaN
# clock       3.0   NaN    NaN
# pineaple    NaN  10.0    NaN
# watermelon  NaN  20.0    NaN

# %%
df['three']=df['one']+df['two']
df
# Out:
#             one   two  three
# apple       1.0   NaN    NaN
# ball        2.0   NaN    NaN
# banana      NaN  30.0    NaN
# clock       3.0   NaN    NaN
# pineaple    NaN  10.0    NaN
# watermelon  NaN  20.0    NaN

# %%
df['filtro']=df['one']>2
df
# Out:
#             one   two  three  filtro
# apple       1.0   NaN    NaN   False
# ball        2.0   NaN    NaN   False
# banana      NaN  30.0    NaN   False
# clock       3.0   NaN    NaN    True
# pineaple    NaN  10.0    NaN   False
# watermelon  NaN  20.0    NaN   False

# %%
#del df['two']
df
df2=df.pop('filtro')

# %%
df
# Out:
#             one   two  three
# apple       1.0   NaN    NaN
# ball        2.0   NaN    NaN
# banana      NaN  30.0    NaN
# clock       3.0   NaN    NaN
# pineaple    NaN  10.0    NaN
# watermelon  NaN  20.0    NaN

# %%
#CASE STUDY

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
ratings.tail(5)
# Out:
#          userId  movieId  rating   timestamp
# 1999995   13567    59725     3.5  1262994714
# 1999996   13567    63062     5.0  1262764337
# 1999997   13567    64957     5.0  1262764172
# 1999998   13567    65216     4.5  1262994367
# 1999999   13567    66203     4.0  1262994418

# %%
tags.tail(10)
# Out:
#         userId  movieId                               tag   timestamp
# 465554  138446     3489                visually appealing  1358983822
# 465555  138446     7045                   family friendly  1358983660
# 465556  138446     7045  Scary Movies To See on Halloween  1358983660
# 465557  138446     7164                         Peter Pan  1358983855
# 465558  138446     7164                visually appealing  1358983855
# 465559  138446    55999                           dragged  1358983772
# 465560  138446    55999                     Jason Bateman  1358983778
# 465561  138446    55999                            quirky  1358983778
# 465562  138446    55999                               sad  1358983772
# 465563  138472      923                     rise to power  1194037967

# %%
movies= "/content/Estructura de datos/movies.csv"
ratings= "/content/Estructura de datos/ratings.csv"
tags= "/content/Estructura de datos/tags.csv"

# %%
#Creamos variables para importar los archivos
movies=pd.read_csv(movies)
ratings=pd.read_csv(ratings)
tags=pd.read_csv(tags)
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
#ver el total de datos
tags.shape
# Out:
# (3683, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
#ver total de datos
ratings.shape
# Out:
# (100836, 4)

# %%
#ver total de datos
movies.shape
# Out:
# (9742, 3)

# %%
#ver total de columnas
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
del ratings["timestamp"]
del tags["timestamp"]

# %%
tags.head(5)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell
# 3       2    89774     Boxing story
# 4       2    89774              MMA

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0
# 5       1       70     3.0
# 6       1      101     5.0
# 7       1      110     4.0
# 8       1      151     5.0
# 9       1      157     5.0

# %%
#buscar datos por columnas, "columna 6"
ratings.iloc[6]
# Out:
# userId       1.0
# movieId    101.0
# rating       5.0
# Name: 6, dtype: float64

# %%
ratings.iloc[580]
# Out:
# userId      6.0
# movieId    31.0
# rating      3.0
# Name: 580, dtype: float64

# %%
print(ratings.iloc[[30,40,50]])
# Out:
#     userId  movieId  rating
# 30       1      552     4.0
# 40       1      733     4.0
# 50       1     1023     5.0

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# std       182.618491   35530.987199       1.042529
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
#calcular el valor minimo
print(ratings["rating"].min())
# Out:
# 0.5

# %%
#calcular el valor máximo
ratings["rating"].max()
# Out:
# 5.0

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000  0.006773 -0.049348
# movieId  0.006773  1.000000 -0.004061
# rating  -0.049348 -0.004061  1.000000

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
filter=ratings["rating"]>5

# %%
filter.any()
# Out:
# False

# %%
mask=ratings["rating"]>3

# %%
print(mask.any())
# Out:
# True

# %%
aux=ratings[mask]
print(aux.shape)
#print()
print(aux.head(3))
# Out:
# (61716, 3)
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
#para ver gráfico
ratings.hist(column="rating",figsize=(7,7))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
#filtro de muestra de Animación
#crear variable
is_animation=movies["genres"].str.contains("Animation")

# %%
#creamos una variable newMovies para contar la columna Animations
newMovies=movies[is_animation]

# %%
movies.shape
# Out:
# (9742, 3)

# %%
newMovies.shape
# Out:
# (611, 3)

# %%
newMovies.head(10)
# Out:
#      movieId                                   title  \
# 0          1                        Toy Story (1995)
# 12        13                            Balto (1995)
# 44        48                       Pocahontas (1995)
# 205      239                   Goofy Movie, A (1995)
# 272      313               Swan Princess, The (1994)
# 322      364                   Lion King, The (1994)
# 483      551  Nightmare Before Christmas, The (1993)
# 488      558                  Pagemaster, The (1994)
# 506      588                          Aladdin (1992)
# 511      594  Snow White and the Seven Dwarfs (1937)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 44          Animation|Children|Drama|Musical|Romance
# 205                Animation|Children|Comedy|Romance
# 272                               Animation|Children
# 322  Adventure|Animation|Children|Drama|Musical|IMAX
# ...

# %%
tags="/content/Estructura de datos/tags.csv"
tags=pd.read_csv(tags)

# %%
tags.head(5)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags["informationsDtaeTime"]=pd.to_datetime(tags["timestamp"],unit="s")

# %%
tags.head(10)
# Out:
#    userId  movieId                tag   timestamp informationsDtaeTime
# 0       2    60756              funny  1445714994  2015-10-24 19:29:54
# 1       2    60756    Highly quotable  1445714996  2015-10-24 19:29:56
# 2       2    60756       will ferrell  1445714992  2015-10-24 19:29:52
# 3       2    89774       Boxing story  1445715207  2015-10-24 19:33:27
# 4       2    89774                MMA  1445715200  2015-10-24 19:33:20
# 5       2    89774          Tom Hardy  1445715205  2015-10-24 19:33:25
# 6       2   106782              drugs  1445715054  2015-10-24 19:30:54
# 7       2   106782  Leonardo DiCaprio  1445715051  2015-10-24 19:30:51
# 8       2   106782    Martin Scorsese  1445715056  2015-10-24 19:30:56
# 9       7    48516       way too long  1169687325  2007-01-25 01:08:45
